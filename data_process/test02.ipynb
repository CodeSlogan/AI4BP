# %%
import pandas as pd

# %%
ppg_path = './data/512_20/ppg_512_20.csv'
abp_path = './data/512_20/abp_512_20.csv'

# %%
ppg_pd = pd.read_csv(ppg_path)
abp_pd = pd.read_csv(abp_path)

# %%
import matplotlib.pyplot as plt

# %%
row = 8

# %%
plt.figure()

y1 = ppg_pd.iloc[row, :]
plt.plot(y1)

plt.show()

# %%
y2 = abp_pd.iloc[row, :]
plt.plot(y2, color='red')

plt.show()
